# %% [markdown]
# # Lab: Exploratory Data Analysis - Used Car Pricing

# %% [markdown]
# ### Exploratory Data Analysis
# Estimated time needed: 30 minutes
#
# Objectives
# After completing this lab you will be able to:
#
#     Explore features or characteristics to predict price of car
#     Analyze patterns and run descriptive statistical analysis
#     Group data based on identified parameters and create pivot tables
#     Identify the effect of independent attributes on price of cars

# %%
# %pip install pandas numpy scipy seaborn
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Downloading numpy-2.3.5-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting scipy
#   Downloading scipy-1.16.3-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jayes\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Downloading matplotlib-3.10.7-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.60.1-cp314-cp314-win_amd64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading kiwisolver-1.4.9-cp314-cp314-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\jayes\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pillow-12.0.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: six>=1.5 in c:\users\jayes\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp314-cp314-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.1 MB 6.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.1 MB 6.7 MB/s eta 0:00:02
#    --------------- ------------------------ 4.2/11.1 MB 6.7 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.1 MB 6.7 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.1 MB 6.7 MB/s eta 0:00:01
#    ------------------------------ --------- 8.4/11.1 MB 6.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.1 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 6.5 MB/s  0:00:01
# Downloading numpy-2.3.5-cp314-cp314-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.9 MB 6.9 MB/s eta 0:00:02
#    -------- ------------------------------- 2.9/12.9 MB 6.8 MB/s eta 0:00:02
#    ------------ --------------------------- 4.2/12.9 MB 6.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.5/12.9 MB 6.7 MB/s eta 0:00:02
#    --------------------- ------------------ 7.1/12.9 MB 6.7 MB/s eta 0:00:01
#    ------------------------- -------------- 8.4/12.9 MB 6.7 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.9 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.9 MB 6.7 MB/s eta 0:00:01
#    -------------------------------------- - 12.6/12.9 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 6.3 MB/s  0:00:02
# Downloading scipy-1.16.3-cp314-cp314-win_amd64.whl (39.4 MB)
#    ---------------------------------------- 0.0/39.4 MB ? eta -:--:--
#    - -------------------------------------- 1.3/39.4 MB 6.8 MB/s eta 0:00:06
#    -- ------------------------------------- 2.9/39.4 MB 6.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.2/39.4 MB 6.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 5.5/39.4 MB 6.7 MB/s eta 0:00:06
#    ------ --------------------------------- 6.8/39.4 MB 6.7 MB/s eta 0:00:05
#    -------- ------------------------------- 8.4/39.4 MB 6.7 MB/s eta 0:00:05
#    --------- ------------------------------ 9.7/39.4 MB 6.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 11.0/39.4 MB 6.7 MB/s eta 0:00:05
#    ------------ --------------------------- 12.6/39.4 MB 6.7 MB/s eta 0:00:04
#    -------------- ------------------------- 13.9/39.4 MB 6.7 MB/s eta 0:00:04
#    --------------- ------------------------ 15.2/39.4 MB 6.7 MB/s eta 0:00:04
#    ----------------- ---------------------- 16.8/39.4 MB 6.7 MB/s eta 0:00:04
#    ------------------ --------------------- 18.1/39.4 MB 6.7 MB/s eta 0:00:04
#    ------------------- -------------------- 19.7/39.4 MB 6.7 MB/s eta 0:00:03
#    --------------------- ------------------ 21.0/39.4 MB 6.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 22.3/39.4 MB 6.7 MB/s eta 0:00:03
#    ------------------------ --------------- 23.9/39.4 MB 6.7 MB/s eta 0:00:03
#    ------------------------- -------------- 25.2/39.4 MB 6.7 MB/s eta 0:00:03
#    --------------------------- ------------ 26.7/39.4 MB 6.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 28.0/39.4 MB 6.7 MB/s eta 0:00:02
#    ------------------------------ --------- 29.6/39.4 MB 6.7 MB/s eta 0:00:02
#    ------------------------------- -------- 30.9/39.4 MB 6.7 MB/s eta 0:00:02
#    -------------------------------- ------- 32.2/39.4 MB 6.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.6/39.4 MB 6.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 35.1/39.4 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------- -- 36.4/39.4 MB 6.7 MB/s eta 0:00:01
#    -------------------------------------- - 37.7/39.4 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  39.1/39.4 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 39.4/39.4 MB 6.5 MB/s  0:00:06
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading matplotlib-3.10.7-cp314-cp314-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.3 MB 6.7 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.3 MB 6.7 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.3 MB 6.7 MB/s eta 0:00:01
#    -------------------------- ------------- 5.5/8.3 MB 6.7 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.3 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.3 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 6.4 MB/s  0:00:01
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ----------------------- ---------------- 1.3/2.3 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 6.1 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp314-cp314-win_amd64.whl (75 kB)
# Downloading pillow-12.0.0-cp314-cp314-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ------- -------------------------------- 1.3/7.1 MB 6.7 MB/s eta 0:00:01
#    -------------- ------------------------- 2.6/7.1 MB 6.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.2/7.1 MB 6.7 MB/s eta 0:00:01
#    ------------------------------ --------- 5.5/7.1 MB 6.7 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.1 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 6.4 MB/s  0:00:01
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, scipy, pandas, contourpy, matplotlib, seaborn
#
#    ----------------------------------------  0/13 [pytz]
#    --- ------------------------------------  1/13 [tzdata]
#    --- ------------------------------------  1/13 [tzdata]
#    ------ ---------------------------------  2/13 [pyparsing]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    ------------------------------ --------- 10/13 [contourpy]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ---------------------------------------- 13/13 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 numpy-2.3.5 pandas-2.3.3 pillow-12.0.0 pyparsing-3.2.5 pytz-2025.2 scipy-1.16.3 seaborn-0.13.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\jayes\AppData\Local\Programs\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\jayes\AppData\Local\Programs\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import piplite
#
# ModuleNotFoundError: No module named 'pandas'

# %%
filepath='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df = pd.read_csv(filepath, header=None)
